# %%
import pandas as pd

hotel_df = pd.read_csv (r"C:\Users\mattd\Documents\2020 Vandy Bootcamp\Class Module 6\weather_data\WeatherPy_vacation.csv")
hotel_df.head(50)
WeatherPy_vacation_df=pd.read_csv (r"C:\Users\mattd\Documents\2020 Vandy Bootcamp\Class Module 6\weather_data\WeatherPy_vacation.csv")
WeatherPy_vacation_df.head(50)
# Out:
#     City          City.1  Max Temp Country Weather Description    Lat     Lng  \
# 0     21          Ouadda     66.92      CF          light rain   8.08   22.40
# 1     27      Bredasdorp     62.60      ZA       moderate rain -34.53   20.04
# 2     39           Gimbi     56.14      ET       moderate rain   9.17   35.83
# 3     45           Ambon     79.00      ID       moderate rain  -3.70  128.18
# 4     49       Porbandar     83.07      IN          light rain  21.64   69.61
# 5     59      Butaritari     83.79      KI          light rain   3.07  172.79
# 6     64        Qaqortoq     51.80      GL          light rain  60.72  -46.03
# 7     67          Vostok     66.96      RU          light rain  46.49  135.88
# 8     69  Saint-Philippe     66.20      RE          light rain -21.36   55.77
# 9     81       Busselton     59.00      AU          light rain -33.65  115.33
# 10    84          Shiyan     69.53      CN          light rain  32.65  110.78
# ...

# %%
mizan_teferi_df = WeatherPy_vacation_df.loc[WeatherPy_vacation_df["City.1"]=="Mizan Teferi"]
mizan_teferi_df
# Out:
#     City        City.1  Max Temp Country Weather Description   Lat    Lng  \
# 64   534  Mizan Teferi     61.41      ET          light rain  6.98  35.58
#
#                    Hotel Name
# 64  Hotel Salayish | ሆቴል ሳላይሽ

# %%
moroto_df = WeatherPy_vacation_df.loc[WeatherPy_vacation_df["City.1"]=="Moroto"]
moroto_df
# Out:
#     City  City.1  Max Temp Country Weather Description   Lat    Lng  \
# 55   434  Moroto     64.51      UG          light rain  2.53  34.67
#
#                           Hotel Name
# 55  Kara-Tunga, Karamoja Safari Camp

# %%
gimbi_df = WeatherPy_vacation_df.loc[WeatherPy_vacation_df["City.1"]=="Gimbi"]
gimbi_df
# Out:
#    City City.1  Max Temp Country Weather Description   Lat    Lng Hotel Name
# 2    39  Gimbi     56.14      ET       moderate rain  9.17  35.83   Sam home

# %%
gondar_df = WeatherPy_vacation_df.loc[WeatherPy_vacation_df["City.1"]=="Gondar"]
gondar_df
# Out:
#     City  City.1  Max Temp Country Weather Description   Lat    Lng  \
# 50   400  Gondar     58.55      ET          light rain  12.6  37.47
#
#        Hotel Name
# 50  L Shape Hotel

# %%
import gmaps
import gmaps.datasets
gmaps.configure(api_key="AIzaSyD8yzsbGbeDg20BCXACfgfj8Lz7JzdHQLs")

# Latitude-longitude pairs
moroto = (2.53, 34.67)
mizan_teferi = (6.98, 35.58)
gimbi = (9.17, 35.83)
gondar = (12.6, 37.47)

fig = gmaps.figure()
fourcities = gmaps.directions_layer(moroto, mizan_teferi, waypoints=[gimbi, gondar], travel_mode='DRIVING')
fig.add_layer(fourcities)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
